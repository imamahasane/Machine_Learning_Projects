# %%
import matplotlib.pyplot as plt

# %%
x = [44.000, 46.400, 43.600, 35.000, 35.000, 32.600, 28.900]
y = [26.944, 25.833, 25.556, 23.056, 21.389, 20.000, 18.889]

# %%
plt.xlabel('Cricket Chirp / 15 second')
# Out:
# Text(0.5, 0, 'Cricket Chirp / 15 second')

# %%
plt.ylabel('Temperature / Celsius')
# Out:
# Text(0, 0.5, 'Temperature / Celsius')

# %%
plt.title('Cricket Chirp and Temperature')
# Out:
# Text(0.5, 1.0, 'Cricket Chirp and Temperature')

# %%
plt.grid(True)

# %%
plt.plot(x, y, 'ro')

# %%
plt.title('Cricket Chirp and Temperature')
plt.xlabel('Cricket Chirp / 15 second')
plt.ylabel('Temperature / Celsius')
plt.grid(True)
plt.plot(x, y, 'ro')
plt.show()

# %% [markdown]
# ## visualization

# %%
import seaborn as sns; sns.set(color_codes = True)
import pandas as pd

# %%
chirp_data = pd.read_csv()
