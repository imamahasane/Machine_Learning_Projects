# %% [markdown]
# ## data visualization

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
correlation = iris.corr()

# %%
correlation
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), cmap = 'coolwarm', annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.set(style = "whitegrid", color_codes = True)

# %%
sns.lmplot(x = "sepal_length", y = "petal_length", hue = "species", data = iris, \
           palette = "Set1", markers = ["o", "s", "D"])

# %%
sns.lmplot(x="sepal_length", y="petal_length", hue="species", data = iris, \
              palette="Set1", fit_reg=False, markers=["o", "s", "D"])

# %%
sns.pairplot(iris, size=5, vars = ["sepal_length", "petal_length"], \
            markers = ["o", "s", "D"], hue = "species")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(iris, markers = ["o", "s", "D"], hue = "species")

# %%
sns.pairplot(iris, kind = "reg", hue = "species", markers = ["o", "s", "D"])

# %%
sns.boxplot(data = iris, orient = "h")
# Out:
# <AxesSubplot:>

# %%
iris["ID"] = iris.index
iris["ratio"] = iris["sepal_length"] / iris["sepal_width"]
sns.lmplot(x = "ID", y = "ratio", data = iris, \
          hue = "species", markers = ["o", "s", "D"], fit_reg = False, legend = True)

# %%
sns.stripplot(x = "species", y = "sepal_length", data = iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.stripplot(x = "species", y = "petal_length", data = iris, jitter = True)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.swarmplot(x = "speci")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/gr/9w8v_1fn48ddjgbpp0c4s5cr0000gn/T/ipykernel_2098/1089467981.py in <module>
# ----> 1 sns.swarmplot(x = "speci")
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    3002         warnings.warn(msg, UserWarning)
#    3003
# -> 3004     plotter = _SwarmPlotter(x, y, hue, data, order, hue_order,
#    3005                             dodge, orient, color, palette)
#    3006     if ax is None:
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, dodge, orient, color, palette)
#    1170                  dodge, orient, color, palette):
#    1171         """Initialize the plotter."""
# -> 1172         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#    1173         self.establish_colors(color, palette, 1)
#    1174
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'speci'
